# %% [markdown]
# <a href="https://colab.research.google.com/github/Astro3033/BO/blob/main/youtube_api_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client

# %%
from googleapiclient.discovery import build
from google.colab import userdata
api_key = userdata.get('AIzaSyBpMwj74tGJchfWkd5JdkPwA49XdRNZ-94')
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_comments(video_url, maxresults = 50):
  if "&" in video_url:
    video_url = video_url.split("&")[0]
  video_id = video_url.split("v=")[1]
  # Fetch top-level comments
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video_id,
      maxResults=maxresults,
      order="relevance"  # Fetch top-liked comments
  )
  response = request.execute()

  comments = []
  for item in response.get('items', []):
      comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
      comments.append(comment)
  return comments

# %%
get_comments("https://www.youtube.com/watch?v=y3Umo_jd5AA&pp=ygUXQ2FsIE5ld3BvcnQgbGV4IGZyaWRtYW4%3D")

# %%
# !pip install google-api-python-client
# !pip install python-telegram-bot
# !pip install selenium
# !pip install python-telegram-bot --upgrade
# !pip install --upgrade pip
# !apt-get update
# !apt install chromium-chromedriver
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !pip install --upgrade chromedriver-binary
# !pip install chromedriver-binary==122.0.6258.0
# !pip install webdriver-manager
# !pip install selenium
import logging
import time
import telegram
from telegram.ext import Updater, CommandHandler
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from googleapiclient.discovery import build
from google.colab import userdata



# Configuración de la API de YouTube
api_key = userdata.get("AIzaSyBpMwj74tGJchfWkd5JdkPwA49XdRNZ-94")
youtube = build('youtube', 'v3', developerKey=api_key)
TELEGRAM_BOT_TOKEN = ("8033773371:AAE0DgwRNDpoGNm_Zob3_CTpnpVta1kx3eQ")


def get_comments(video_url, maxresults=50):
    if "&" in video_url:
        video_url = video_url.split("&")[0]
    video_id = video_url.split("v=")[1]
    # Fetch top-level comments
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=maxresults,
        order="relevance"  # Fetch top-liked comments
    )
    response = request.execute()

    comments = []
    for item in response.get('items', []):
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        comments.append(comment)
    return comments


get_comments(
    "https://www.youtube.com/watch?v=y3Umo_jd5AA&pp=ygUXQ2FsIE5ld3BvcnQgbGV4IGZyaWRtYW4%3D")

options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Para ejecutar en modo sin interfaz gráfica
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options=options)  # Use the ChromeOptions object directly
driver.get("https://www.google.com")
print(driver.title)

driver.quit()

# Lista de reproducción de YouTube
YOUTUBE_PLAYLIST = [
    "https://music.youtube.com/playlist?list=PLL5uFnCndOajaTgkSpxdZBmYEFNtzSZij",
    "https://music.youtube.com/playlist?list=PLL5uFnCndOajaTgkSpxdZBmYEFNtzSZij",
    "https://music.youtube.com/playlist?list=PLL5uFnCndOajaTgkSpxdZBmYEFNtzSZij",
    "https://music.youtube.com/playlist?list=PLL5uFnCndOajaTgkSpxdZBmYEFNtzSZij",
    "https://music.youtube.com/playlist?list=PLL5uFnCndOajaTgkSpxdZBmYEFNtzSZij",
    "https://music.youtube.com/playlist?list=PLL5uFnCndOajaTgkSpxdZBmYEFNtzSZij"


]



# Configuración del bot de Telegram
Updater= Updater(TELEGRAM_BOT_TOKEN, use_context=True)
dispatcher = Updater.dispatcher
from telegram import Update
from telegram.ext import Application, CommandHandler, ContextTypes

# Tu token de Telegram
TELEGRAM_BOT_TOKEN = '8033773371:AAE0DgwRNDpoGNm_Zob3_CTpnpVta1kx3eQ'

# Configuración del bot de Telegram
application = Application.builder().token(TELEGRAM_BOT_TOKEN).build()

# Define una función para manejar el comando /start
async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text("¡Hola! AROHA.")

# Añadir el handler para el comando /start
application.add_handler(CommandHandler("start", start))

# Iniciar el bot (este código lo ejecuta en segundo plano)
application.run_polling()


#  el ID de video desde la URL
def obtener_id_video(url):
    #  ID de un video de YouTube
    match = re.search(r'(?:v=|embed\/|youtu\.be\/)([a-zA-Z0-9_-]+)', url)
    if match:
        return match.group(1)
    return None

# Función de bienvenida del bot
def start(update, context):
    update.message.reply_text(
        "Hola AROHA💜💜💜! /stream para ver estrategias de reproducción."
    )

# Función para enviar un mensaje de stream
def stream(update, context):
    url_video = "https://www.youtube.com/watch?v=WCQGZ_FlUAE"
    id_video = obtener_id_video(url_video)
    if id_video:
        message = (
            f"**¡HAGAMOS streaming de Twilingth!!**\n\n"
            f"https://www.youtube.com/watch?v={id_video}\n\n"
            "⚡ **Consejos para que el streaming cuente:**\n"
            "✔ No repitas en bucle, alterna con otros videos.\n"
            "✔ Mantén el volumen al 50% o más.\n"
            "✔ No pauses ni adelantes.\n"
            "✔ Usa varias cuentas y dispositivos.\n\n"
            "💜 **Vamos AROHA, sigamos apoyando a ASTRO!** 💜"
        )
        update.message.reply_text(message, parse_mode=telegram.ParseMode.MARKDOWN)
    else:
        update.message.reply_text("No se pudo encontrar el ID del video.")

# Función para enviar la lista de reproducción
def playlist(update, context):
    message = "**Lista de reproducción de ASTRO**\n\n"
    for idx, video in enumerate(YOUTUBE_PLAYLIST, 1):
        id_video = obtener_id_video(video)
        if id_video:
            message += f"{idx}. [Video {idx}](https://www.youtube.com/watch?v={id_video})\n"
    message += "\n¡Disfrutemos de la música de ASTRO y hagamos streaming juntas!"
    update.message.reply_text(message, parse_mode=telegram.ParseMode.MARKDOWN)

# Comandos del bot
dispatcher.add_handler(CommandHandler("start", start))
dispatcher.add_handler(CommandHandler("stream", stream))
dispatcher.add_handler(CommandHandler("playlist", playlist))

# Iniciar el bot
updater.start_polling()
print("HOLA AROHA....")

#  video usando Selenium
def interactuar_con_video(url):
    driver.get(url)  # Abrir la URL
    time.sleep(5)  # Espera a que cargue la página de YouTube

    # Reproducir el video (si no se reproduce automáticamente)
    play_button = driver.find_element(By.CSS_SELECTOR, 'button.ytp-play-button')
    play_button.click()
    time.sleep(2)  # Espera un poco

    # Pausar el video
    pause_button = driver.find_element(By.CSS_SELECTOR, 'button.ytp-play-button')
    pause_button.click()
    time.sleep(2)  # Pausa por 2 segundos

    # Reanudar el video
    play_button.click()
    time.sleep(3)

    # Avanzar 10 segundos
    player = driver.find_element(By.CSS_SELECTOR, '.video-stream')
    player.send_keys(Keys.RIGHT)
    time.sleep(1)  # Espera para que el video avance

    # Retroceder 10 segundos
    player.send_keys(Keys.LEFT)
    time.sleep(1)

    # Detener la interacción
    driver.quit()

# Ejecutar una interacción
interactuar_con_video("https://www.youtube.com/watch?v=WCQGZ_FlUAE")

# Tu token de Telegram
TELEGRAM_BOT_TOKEN = '8033773371:AAE0DgwRNDpoGNm_Zob3_CTpnpVta1kx3eQ'

# Configuración del bot de Telegram
application = Application.builder().token(TELEGRAM_BOT_TOKEN).build()

# Define una función para manejar el comando /start
async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text("¡Hola! AROHA.")

# Añadir el handler para el comando /start
application.add_handler(CommandHandler("start", start))

# Iniciar el bot (este código lo ejecuta en segundo plano)
application.run_polling()


#  el ID de video desde la URL
def obtener_id_video(url):
    #  ID de un video de YouTube
    match = re.search(r'(?:v=|embed\/|youtu\.be\/)([a-zA-Z0-9_-]+)', url)
    if match:
        return match.group(1)
    return None

# Función de bienvenida del bot
def start(update, context):
    update.message.reply_text(
        "Hola AROHA💜💜💜! /stream para ver estrategias de reproducción."
    )

# Función para enviar un mensaje de stream
def stream(update, context):
    url_video = "https://www.youtube.com/watch?v=WCQGZ_FlUAE"
    id_video = obtener_id_video(url_video)
    if id_video:
        message = (
            f"**¡HAGAMOS streaming de Twilingth!!**\n\n"
            f"https://www.youtube.com/watch?v={id_video}\n\n"
            "⚡ **Consejos para que el streaming cuente:**\n"
            "✔ No repitas en bucle, alterna con otros videos.\n"
            "✔ Mantén el volumen al 50% o más.\n"
            "✔ No pauses ni adelantes.\n"
            "✔ Usa varias cuentas y dispositivos.\n\n"
            "💜 **Vamos AROHA, sigamos apoyando a ASTRO!** 💜"
        )
        update.message.reply_text(message, parse_mode=telegram.ParseMode.MARKDOWN)
    else:
        update.message.reply_text("No se pudo encontrar el ID del video.")

# Función para enviar la lista de reproducción
def playlist(update, context):
    message = "**Lista de reproducción de ASTRO**\n\n"
    for idx, video in enumerate(YOUTUBE_PLAYLIST, 1):
        id_video = obtener_id_video(video)
        if id_video:
            message += f"{idx}. [Video {idx}](https://www.youtube.com/watch?v={id_video})\n"
    message += "\n¡Disfrutemos de la música de ASTRO y hagamos streaming juntas!"
    update.message.reply_text(message, parse_mode=telegram.ParseMode.MARKDOWN)

# Comandos del bot
dispatcher.add_handler(CommandHandler("start", start))
dispatcher.add_handler(CommandHandler("stream", stream))
dispatcher.add_handler(CommandHandler("playlist", playlist))

# Iniciar el bot
updater.start_polling()
print("HOLA AROHA....")

#  video usando Selenium
def interactuar_con_video(url):
    driver.get(url)  # Abrir la URL
    time.sleep(5)  # Espera a que cargue la página de YouTube

    # Reproducir el video (si no se reproduce automáticamente)
    play_button = driver.find_element(By.CSS_SELECTOR, 'button.ytp-play-button')
    play_button.click()
    time.sleep(2)  # Espera un poco

    # Pausar el video
    pause_button = driver.find_element(By.CSS_SELECTOR, 'button.ytp-play-button')
    pause_button.click()
    time.sleep(2)  # Pausa por 2 segundos

    # Reanudar el video
    play_button.click()
    time.sleep(3)

    # Avanzar 10 segundos
    player = driver.find_element(By.CSS_SELECTOR, '.video-stream')
    player.send_keys(Keys.RIGHT)
    time.sleep(1)  # Espera para que el video avance

    # Retroceder 10 segundos
    player.send_keys(Keys.LEFT)
    time.sleep(1)

    # Detener la interacción
    driver.quit()

# Ejecutar una interacción
interactuar_con_video("https://www.youtube.com/watch?v=WCQGZ_FlUAE")
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,378 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 1,380 kB in 1s (1,028 kB/s)
# Reading package lists... Done
# ...
